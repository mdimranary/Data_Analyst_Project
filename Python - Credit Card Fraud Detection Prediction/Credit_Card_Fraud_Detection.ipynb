# %%
# dataset - https://www.kaggle.com/mlg-ulb/creditcardfraud

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import matplotlib
print(f"pandas version : Pandas {pd.__version__}")
print(f"numpy version : Numpy{np.__version__}")
print(f"matplotlip : matplotlib {matplotlib.__version__}")
print(f"seaborn version : seaborn {sns.__version__}")
# Out:
# pandas version : Pandas 1.0.3
# numpy version : Numpy1.18.1
# matplotlip : matplotlib 3.1.3
# seaborn version : seaborn 0.10.0

# %%
df = pd.read_csv(r"C:\Users\Imran\Desktop\Ivy classes\GITHUB Project\creditcard.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.919560e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.688174e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.769071e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.782312e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552563e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.010663e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.694249e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.927028e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.137024e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.768627e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.170318e-16      1.020713   -4.797473     -0.762494
# ...

# %% [markdown]
# # Observing Null values and duplicate values

# %%
# null value
df.isnull().sum().sum()
# Out:
# 0

# %%
# dublocate
print(len(df.drop_duplicates()))
print(len(df[df.duplicated()]))
# Out:
# 283726
# 1081

# %%
1081/283726
# Out:
# 0.0038100138866371076

# %%
len(df[(df['Class'] ==1) & (df.duplicated())])
# Out:
# 19

# %%
len(df[(df['Class'] ==0 ) & (df.duplicated())])
# Out:
# 1062

# %%
19/1062 # As the % of duplicate values of fraud and geniun are same as in orignal dataset so we can remove duplicate
# Out:
# 0.017890772128060263

# %% [markdown]
# # Droping duplicates

# %%
df.drop_duplicates(inplace = True)

# %%
df.reset_index(inplace = True, drop = True)

# %%
df[['Time','Amount','Class']].describe()
# Out:
#                 Time         Amount          Class
# count  283726.000000  283726.000000  283726.000000
# mean    94811.077600      88.472687       0.001667
# std     47481.047891     250.399437       0.040796
# min         0.000000       0.000000       0.000000
# 25%     54204.750000       5.600000       0.000000
# 50%     84692.500000      22.000000       0.000000
# 75%    139298.000000      77.510000       0.000000
# max    172792.000000   25691.160000       1.000000

# %%
len(df) # after removing duplicates
# Out:
# 283726

# %%
# convert all the columns to lower case
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
#        'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
#        'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
#        'class'],
#       dtype='object')

# %%
# observing columns  by visual plot

# %%
import warnings
warnings.filterwarnings("ignore")
plt.figsize=(20,20)
sns.distplot(df['amount'], kde = 0)
plt.show()

# %%
#Observation
# 1. Data Set with respect to Amount is highly skewed ! (Right skewed - positive skeweness)
# There is no negetive value
# possibility lots of zero values

# %%
df['amount'].quantile(0.79) # almost 80% of data is below 100
# Out:
# 96.31

# %%
plt.figsize = (20,20)
sns.distplot(df['time'], kde = 0)
plt.show()

# %%
#observation
#possibility tranaction starts from morning time or an early morning because in the late night 
# or in the early morning transaction usally take place less in number which can be prove through the above plot

# %%
df['class'].value_counts().plot(kind = 'pie', labels = ['Genuin','Fraud'],
                                autopct='%0.3f%%',  pctdistance=2.5, labeldistance=1.2 )

# %%
#observation
# Imbalanced dataset 99.83% genuin transaction and only .17% data are fraud

# %%
df.hist(figsize = (25,25)) #observing outlier
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# # Outliers Treatment

# %%
check_outluer = df.drop(columns = ['class','time', 'amount']).columns
sns.set(color_codes = True)
plt.subplots_adjust(hspace = .4)
plt.figure(figsize = (25,30))

for i in range(len(df.drop(columns = ['class','time', 'amount']).columns)):
    plt.subplot(8,4,i+1)
    plt.boxplot(df[check_outluer[i]])
    plt.title(check_outluer[i])
plt.show()


# looking at outliers of continious variable

# %%
check_outluer1 =  ['class','time', 'amount']

sns.set(color_codes = True)
plt.subplots_adjust(hspace = .5)
plt.figure(figsize = (15,8))

for i in range(len(check_outluer1)):
    plt.subplot(2,2,i+1)
    sns.boxplot(df[check_outluer1[i]])
    plt.title(check_outluer1[i])
plt.show()

# %%
df['amount'].quantile(.999989) # removing outlier from amount column
# Out:
# 12788.401681031506

# %%
df = df[(df['amount'] <= df['amount'].quantile(.999989))]

# %%
len(df)
# Out:
# 283722

# %%
# 283722 rows are there after removing duplicates and outlier

# %%
df.reset_index(inplace = True, drop = True)

# %% [markdown]
# # Scaling the amount column

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
sc.fit_transform(df['amount'].values.reshape(-1,1))
# Out:
# array([[ 0.25677384],
#        [-0.35750452],
#        [ 1.21433399],
#        ...,
#        [-0.08496109],
#        [-0.3269432 ],
#        [ 0.53847312]])

# %%
df['amount_scaled'] = sc.fit_transform(df['amount'].values.reshape(-1,1))

# %%
df
# Out:
#             time         v1         v2        v3        v4        v5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 283717  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 283718  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 283719  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 283720  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 283721  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               v6        v7        v8        v9  ...       v22       v23  \
# ...

# %% [markdown]
# # Comparing amount and transaction class

# %%
plt.figure(figsize=(14,6))
# Let's explore the Amount by Class and see the distribuition of Amount transactions
#plt.subplot(121)
ax = sns.boxplot(x ="class",y="amount",
                 data=df)
ax.set_title("Class x time", fontsize=20)
ax.set_xlabel("Is Fraud?", fontsize=16)
ax.set_ylabel("amount", fontsize = 16)
# Out:
# Text(0, 0.5, 'amount')

# %%
# Geniun transaction has highest value then fradulent transaction so amount column is does not have much importance
# so we will remove the amount column while creating model and keep the amount_scaled colum

# %%
y = df['class']
x = df.drop(['class','time','amount'], axis = 1)
# class is a dependent variable so its need to be removed
# in time and amount column we have not found any pattern or info which helps to find the genuin and fraud transaction so we are removing it
# keeping the amount_scaled column and 28 PCA columns

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.datasets import make_classification
print('Original dataset shape %s' % Counter(y))
rus = RandomOverSampler(random_state = 42)
X_res,y_res = rus.fit_resample(x,y)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Using TensorFlow backend.
# Original dataset shape Counter({0: 283249, 1: 473})
# Resampled dataset shape Counter({0: 283249, 1: 283249})

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
X_train, X_test, y_train,y_test = train_test_split(X_res,y_res, test_size = .3, random_state = 42 )

# %% [markdown]
# ### Now trying different sklrean model to find the best result

# %% [markdown]
# # Random Forest

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(X_test)

# %%
y_pred_proba = rfc.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred)
auc = roc_auc_score(y_test, y_pred)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
cnf_matrics = confusion_matrix(y_test,y_pred)
sns.heatmap(pd.DataFrame(cnf_matrics), annot = True, cmap = 'Blues', fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Expected')
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84958
#            1       1.00      1.00      1.00     84992
#
#     accuracy                           1.00    169950
#    macro avg       1.00      1.00      1.00    169950
# weighted avg       1.00      1.00      1.00    169950

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dc = DecisionTreeClassifier()
dc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dc.predict(X_test)

# %%
y_pred_proba = dc.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred)
auc = roc_auc_score(y_test, y_pred)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
cnf_matrics = confusion_matrix(y_test,y_pred)
sns.heatmap(pd.DataFrame(cnf_matrics), annot = True, cmap = 'Blues', fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Expected')
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84958
#            1       1.00      1.00      1.00     84992
#
#     accuracy                           1.00    169950
#    macro avg       1.00      1.00      1.00    169950
# weighted avg       1.00      1.00      1.00    169950

# %% [markdown]
# # K NEAREST NEIGHBORS

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsRegressor()
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = knn.predict(X_test)

# %%
y_pred = round(pd.DataFrame(y_pred))

# %%
cnf_matrics = confusion_matrix(y_test,y_pred)
sns.heatmap(pd.DataFrame(cnf_matrics), annot = True, cmap = 'Blues', fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Expected')
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84958
#            1       1.00      1.00      1.00     84992
#
#     accuracy                           1.00    169950
#    macro avg       1.00      1.00      1.00    169950
# weighted avg       1.00      1.00      1.00    169950

# %% [markdown]
# # BAGGING

# %%
from sklearn.ensemble import BaggingClassifier
bag= BaggingClassifier(dc)
bag.fit(X_train,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier())

# %%
y_pred = bag.predict(X_test)

# %%
y_pred = round(pd.DataFrame(y_pred))

# %%
cnf_matrics = confusion_matrix(y_test,y_pred)
sns.heatmap(pd.DataFrame(cnf_matrics), annot = True, cmap = 'Blues', fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Expected')
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84958
#            1       1.00      1.00      1.00     84992
#
#     accuracy                           1.00    169950
#    macro avg       1.00      1.00      1.00    169950
# weighted avg       1.00      1.00      1.00    169950

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
cnf_matrics = confusion_matrix(y_test,y_pred)
sns.heatmap(pd.DataFrame(cnf_matrics), annot = True, cmap = 'Blues', fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Expected')
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     84958
#            1       0.97      0.92      0.95     84992
#
#     accuracy                           0.95    169950
#    macro avg       0.95      0.95      0.95    169950
# weighted avg       0.95      0.95      0.95    169950

# %% [markdown]
# ## From all the above preditive model we found best confusion_metrics, classification_report and prediction from Random Forest Model
